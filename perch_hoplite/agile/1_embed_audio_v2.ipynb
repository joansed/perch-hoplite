# %%
#%% @title Imports
from IPython.display import display
import ipywidgets as widgets
from etils import epath
import numpy as np

from perch_hoplite.agile import colab_utils
from perch_hoplite.agile import embed
from perch_hoplite.agile import source_info
from perch_hoplite.db import interface
from perch_hoplite.db import brutalism

# %% [markdown]
# ## Embed

# %%
#@title Configuration { vertical-output: true }

#@markdown Configure the raw dataset location(s).  The format is a mapping from
#@markdown a dataset_name to a (base_path, fileglob) pair.  Note that the file
#@markdown globs are case sensitive.  The dataset name can be anything you want.
#
#@markdown This structure allows you to move your data around without having to
#@markdown re-embed the dataset.  The generated embedding database will be
#@markdown placed in the base path. This allows you to simply swap out
#@markdown the base path here if you ever move your dataset.

#@markdown By default we only process one dataset at a time.  Re-run this entire notebook
#@markdown once per dataset.  The embeddings database will be located in the
#@markdown database_base_path.

#@markdown For example, we might set dataset_base_path to '/home/me/myproject',
#@markdown and use the glob '*/*.wav' if all of the audio files have filepaths
#@markdown like '/home/me/myproject/site_XYZ/audio_ABC.wav'
dataset_name = 'INCT17'  #@param {type:'string'}
dataset_base_path = '/home/Sedlar/data/INCT17'  #@param {type:'string'}
dataset_fileglob = '*.wav'  #@param {type:'string'}
#@markdown You do not need to change this unless you want to maintain multiple
#@markdown distinct embedding databases.
db_path = None #@param

#@markdown Choose a supported model: `perch_8` or `birdnet_v2.3` are most common
#@markdown for birds. Other choices include `surfperch` for coral reefs or
#@markdown `multispecies_whale` for marine mammals.
model_choice = 'perch_8'  #@param['perch_8', 'humpback', 'multispecies_whale', 'surfperch', 'birdnet_V2.3']

#@markdown File sharding automatically splits audio files into one-minute chunks
#@markdown for embedding. This limits both system and GPU memory usage,
#@markdown especially useful when working with long files (>1 hour).
use_file_sharding = True  #@param {type:'boolean'}

audio_glob = source_info.AudioSourceConfig(
    dataset_name=dataset_name,
    base_path=dataset_base_path,
    file_glob=dataset_fileglob,
    min_audio_len_s=1.0,
    target_sample_rate_hz=-2,
    shard_len_s=60.0 if use_file_sharding else None,
)

configs = colab_utils.load_configs(
    source_info.AudioSources((audio_glob,)),
    db_path,
    model_config_key=model_choice,
    db_key = 'sqlite_usearch')
configs
# Out:
# AgileConfigs(audio_sources_config=AudioSources(audio_globs=(AudioSourceConfig(dataset_name='INCT17', base_path='/home/Sedlar/data/INCT17', file_glob='*.wav', min_audio_len_s=1.0, target_sample_rate_hz=-2, shard_len_s=60.0, max_shards_per_file=None),)), db_config=DBConfig(db_key='sqlite_usearch', db_config=db_path: !!python/object/apply:etils.epath.gpath.PosixGPath
# - /
# - home
# - Sedlar
# - data
# - INCT17
# usearch_cfg:
#   dtype: float16
#   embedding_dim: 1280
#   expansion_add: 256
#   expansion_search: 128
#   metric_name: IP
# ), model_config=ModelConfig(model_key='taxonomy_model_tf', embedding_dim=1280, model_config=hop_size_s: 5.0
# model_path: ''
# sample_rate: 32000
# tfhub_version: 8
# window_size_s: 5.0
# ))

# %%
#@title Initialize the DB { vertical-output: true }
global db
db = configs.db_config.load_db()
num_embeddings = db.count_embeddings()

print('Initialized DB located at ', configs.db_config.db_config.db_path)

def drop_and_reload_db(_) -> interface.HopliteDBInterface:
  db_path = epath.Path(configs.db_config.db_config.db_path)
  for fp in db_path.glob('hoplite.sqlite*'):
    fp.unlink()
  (db_path / 'usearch.index').unlink()
  print('\n Deleted previous db at: ', configs.db_config.db_config.db_path)
  db = configs.db_config.load_db()

drop_existing_db = True  #@param[True, False]

if num_embeddings > 0 and drop_existing_db:
  print('Existing DB contains datasets: ', db.get_dataset_names())
  print('num embeddings: ', num_embeddings)
  print('\n\nClick the button below to confirm you really want to drop the database at ')
  print(f'{configs.db_config.db_config.db_path}\n')
  print(f'This will permanently delete all {num_embeddings} embeddings from the existing database.\n')
  print('If you do NOT want to delete this data, set `drop_existing_db` above to `False` and re-run this cell.\n')

  button = widgets.Button(description='Delete database?')
  button.on_click(drop_and_reload_db)
  display(button)
# Out:
# Initialized DB located at  /home/Sedlar/data/INCT17

# %%
#@title Run the embedding { vertical-output: true }

print(f'Embedding dataset: {audio_glob.dataset_name}')

worker = embed.EmbedWorker(
    audio_sources=configs.audio_sources_config,
    db=db,
    model_config=configs.model_config)

worker.process_all(target_dataset_name=audio_glob.dataset_name)

print('\n\nEmbedding complete, total embeddings: ', db.count_embeddings())
# Out:
# Embedding dataset: INCT17
# 2025-05-07 17:19:56.550044: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 55971840 exceeds 10% of free system memory.
#   0%|          | 0/20532 [00:00<?, ?it/s]WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200309_171500_43_46.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201123_003000_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200113_193000_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201114_191500_8_11.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200209_183000_41_44.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200203_003000_44_47.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200123_211500_40_43.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200111_021500_37_40.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201128_030000_55_58.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191217_213000_46_49.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191220_020000_12_15.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191217_233000_57_60.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200131_210000_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191217_233000_29_32.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200317_043000_15_18.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200111_201500_11_14.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200111_201500_21_24.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191217_183000_56_59.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
#   0%|          | 18/20532 [00:00<01:56, 175.38it/s]WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201123_010000_49_52.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201114_181500_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200323_001500_29_32.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200317_174500_27_30.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201128_170000_2_5.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200128_174500_0_3.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200120_040000_8_11.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200331_180000_36_39.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200211_041500_23_26.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200107_030000_32_35.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201126_040000_53_56.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200311_231500_34_37.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200111_001500_45_48.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200210_003000_55_58.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201128_020000_5_8.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200208_174500_45_48.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200113_003000_3_6.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200128_174500_27_30.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200201_001500_24_27.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
#   0%|          | 37/20532 [00:00<01:54, 179.26it/s]WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200307_190000_17_20.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201128_180000_3_6.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200131_220000_48_51.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201128_190000_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200131_220000_12_15.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191227_231500_21_24.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201112_040000_26_29.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200113_193000_53_56.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201127_220000_35_38.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200107_230000_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191222_004500_18_21.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191218_220000_3_6.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200113_183000_37_40.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200210_003000_30_33.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201123_233000_43_46.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191217_010000_28_31.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200209_213000_11_14.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201109_020000_12_15.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
#   0%|          | 55/20532 [00:00<01:57, 173.94it/s]WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191217_024500_7_10.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200131_220000_40_43.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191205_211500_40_43.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191227_211500_39_42.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200226_010000_8_11.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201110_000000_1_4.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191222_181500_30_33.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200218_200000_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200113_033000_18_21.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200311_201500_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200320_023000_50_53.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200107_000000_16_19.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200314_043000_18_21.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200113_193000_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200110_040000_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200123_021500_9_12.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200119_040000_44_47.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201128_190000_27_30.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
#   0%|          | 73/20532 [00:00<01:56, 175.62it/s]WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191227_013000_28_31.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201115_033000_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200131_220000_8_11.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200107_010000_28_31.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200320_213000_14_17.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200202_183000_1_4.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201110_190000_34_37.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200225_220000_23_26.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200113_013000_57_60.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200219_030000_30_33.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200111_231500_18_21.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200107_220000_47_50.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200209_174500_52_55.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200229_211500_45_48.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200313_203000_27_30.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20201114_221500_57_60.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191222_031500_40_43.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20200320_183000_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20191215_184500_4_7.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Sedlar/data/INCT17/INCT17_20
/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 10
#       3 print(f'Embedding dataset: {audio_glob.dataset_name}')
#       5 worker = embed.EmbedWorker(
#       6     audio_sources=configs.audio_sources_config,
#       7     db=db,
#       8     model_config=configs.model_config)
# ---> 10 worker.process_all(target_dataset_name=audio_glob.dataset_name)
#      12 print('\n\nEmbedding complete, total embeddings: ', db.count_embeddings())
#
# File ~/miniforge3/envs/hoplite/lib/python3.10/site-packages/perch_hoplite/agile/embed.py:220, in EmbedWorker.process_all(self, target_dataset_name)
#     216 for source_id in self.audio_sources.iterate_all_sources(
#     217     target_dataset_name
#     218 ):
#     219   for emb_source_id, embedding in self.process_source_id(source_id):
# --> 220     self.db.insert_embedding(embedding, emb_source_id)
#     221 self.db.commit()
#
# File ~/miniforge3/envs/hoplite/lib/python3.10/site-packages/perch_hoplite/db/sqlite_usearch_impl.py:267, in SQLiteUsearchDB.insert_embedding(self, embedding, source)
#     264   self._ui_mem.load(self._usearch_filepath.as_posix())
#     265   self.ui = self._ui_mem
# --> 267 self.ui.add(embedding_id, embedding.astype(self.embedding_dtype))
#     268 return embedding_id
#
# File ~/miniforge3/envs/hoplite/lib/python3.10/site-packages/usearch/index.py:666, in Index.add(self, keys, vectors, copy, threads, log, progress)
#     627 def add(
#     628     self,
#     629     keys: KeyOrKeysLike,
#    (...)
#     635     progress: Optional[ProgressCallback] = None,
#     636 ) -> Union[int, np.ndarray]:
#     637     """Inserts one or move vectors into the index.
#     638
#     639     For maximal performance the `keys` and `vectors`
#    (...)
#     664     :type: Union[int, np.ndarray]
#     665     """
# --> 666     return _add_to_compiled(
#     667         self._compiled,
#     668         keys=keys,
#     669         vectors=vectors,
#     670         copy=copy,
#     671         threads=threads,
#     672         log=log,
#     673         progress=progress,
#     674     )
#
# File ~/miniforge3/envs/hoplite/lib/python3.10/site-packages/usearch/index.py:275, in _add_to_compiled(compiled, keys, vectors, copy, threads, log, progress)
#     273     pbar.close()
#     274 else:
# --> 275     compiled.add_many(keys, vectors, copy=copy, threads=threads, progress=progress)
#     277 return keys
#
# RuntimeError: Operation has been terminated

# %%
#@title Per dataset statistics { vertical-output: true }

for dataset in db.get_dataset_names():
  print(f'\nDataset \'{dataset}\':')
  print('\tnum embeddings: ', db.get_embeddings_by_source(dataset, source_id=None).shape[0])
# Out:
# Dataset 'INCT17':
# 	num embeddings:  11201

# %%
#@title Show example embedding

q = db.get_embedding(db.get_one_embedding_id())
# %time results, scores = brutalism.brute_search(worker.db, query_embedding=q, search_list_size=128, score_fn=np.dot)
print([int(r.embedding_id) for r in results])
# Out:
# CPU times: user 376 ms, sys: 6.06 ms, total: 382 ms
# Wall time: 374 ms
# [1, 2811, 10832, 7236, 8903, 95, 6694, 10712, 7773, 1560, 502, 7602, 5129, 4595, 5543, 742, 11057, 6562, 5035, 7059, 9862, 6149, 9483, 9223, 5661, 9289, 6624, 3861, 5562, 3281, 4299, 2559, 10410, 5224, 511, 5854, 6961, 8396, 4297, 7863, 2582, 8777, 3600, 1913, 8858, 1575, 5584, 10016, 8424, 1722, 6357, 4303, 7217, 3810, 10402, 4113, 8253, 4489, 10396, 10550, 188, 3135, 5910, 8169, 7319, 10988, 265, 2190, 3762, 1403, 10564, 10972, 7362, 7278, 7526, 10056, 5581, 755, 6651, 2097, 9396, 2431, 7788, 1153, 3062, 5331, 6659, 3257, 3003, 98, 9390, 4094, 10172, 5666, 6006, 8468, 2488, 8689, 6229, 2158, 331, 7706, 4885, 800, 9639, 1412, 8697, 3147, 1895, 5586, 10442, 1774, 10221, 9062, 2830, 6785, 7740, 4915, 6428, 11192, 8664, 3776, 3417, 2356, 8808, 3911, 4462, 3427]
